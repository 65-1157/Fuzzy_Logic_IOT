# %%
# https://towardsdatascience.com/apply-function-to-pandas-dataframe-rows-76df74165ee4

# %%
! pip install plotly_express
# Para usar as funções de visualização
# Não há necessidade de instalar novamente, uma vez feita a instalação. A importação é feita cada vez para uso.
# Out:
# Requirement already satisfied: plotly_express in c:\users\aferr\anaconda3\lib\site-packages (0.4.1)
# Requirement already satisfied: numpy>=1.11 in c:\users\aferr\anaconda3\lib\site-packages (from plotly_express) (1.17.4)
# Requirement already satisfied: statsmodels>=0.9.0 in c:\users\aferr\anaconda3\lib\site-packages (from plotly_express) (0.10.2)
# Requirement already satisfied: patsy>=0.5 in c:\users\aferr\anaconda3\lib\site-packages (from plotly_express) (0.5.1)
# Requirement already satisfied: plotly>=4.1.0 in c:\users\aferr\anaconda3\lib\site-packages (from plotly_express) (4.2.1)
# Requirement already satisfied: pandas>=0.20.0 in c:\users\aferr\anaconda3\lib\site-packages (from plotly_express) (0.25.3)
# Requirement already satisfied: scipy>=0.18 in c:\users\aferr\anaconda3\lib\site-packages (from plotly_express) (1.4.1)
# Requirement already satisfied: six in c:\users\aferr\anaconda3\lib\site-packages (from patsy>=0.5->plotly_express) (1.15.0)
# Requirement already satisfied: retrying>=1.3.3 in c:\users\aferr\anaconda3\lib\site-packages (from plotly>=4.1.0->plotly_express) (1.3.3)
# Requirement already satisfied: pytz>=2017.2 in c:\users\aferr\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2019.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\aferr\anaconda3\lib\site-packages (from pandas>=0.20.0->plotly_express) (2.8.0)

# %%
import random
import plotly
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.feature_selection import chi2
# %matplotlib inline
import pandas_profiling

# %%
import plotly_express as px

# %%
qws = pd.read_csv("qwsA.csv")
# carregamento do dataset

# %%
qws = pd.DataFrame(qws)

# %%
qws.head(3)
# Out:
#    Response Time  Availability  Throughput  Succesability  Reliability  \
# 0          45.00            83        27.2             50         97.4
# 1          71.75           100        14.6             88         85.5
# 2         117.00           100        23.4             83         88.0
#
#    Compliance  Best Practices  Latency  Documentation  WsRF  Class  \
# 0          89              91    43.00             58   100      1
# 1          78              80    64.42             86    93      1
# 2         100              87   111.00             59    90      1
#
#         Service Name                                       WSDL Address
# 0  DictionaryService  http://www.mindswap.org/2002/services/Dictiona...
# 1          MyService          http://mydispatch.com/myservice.asmx?wsdl
# 2                aba  http://www.quentinsagerconsulting.com/wsdl/aba...

# %%
qws.tail(2)
# Out:
#      Response Time  Availability  Throughput  Succesability  Reliability  \
# 362        6962.85            28         0.5             21         30.0
# 363        1680.16            16         2.0              7         12.5
#
#      Compliance  Best Practices  Latency  Documentation  WsRF  Class  \
# 362          78              69  6915.08              5    32      4
# 363          89              72  1667.22             11    30      4
#
#              Service Name                                       WSDL Address
# 362  SKOSThesaurusService  http://nbii-thesaurus.ornl.gov/ws/services/SKO...
# 363             sugarsoap  http://axonsolutions.com.au/sugarcrm/SugarSuit...

# %%
qws.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 364 entries, 0 to 363
# Data columns (total 13 columns):
# Response Time     364 non-null float64
# Availability      364 non-null int64
# Throughput        364 non-null float64
# Succesability     364 non-null int64
# Reliability       364 non-null float64
# Compliance        364 non-null int64
# Best Practices    364 non-null int64
# Latency           364 non-null float64
# Documentation     364 non-null int64
# WsRF              364 non-null int64
# Class             364 non-null int64
# Service Name      364 non-null object
# WSDL Address      364 non-null object
# dtypes: float64(4), int64(7), object(2)
# memory usage: 37.1+ KB

# %%
round(qws.describe(),2)
# Out:
#        Response Time  Availability  Throughput  Succesability  Reliability  \
# count         364.00        364.00      364.00         364.00       364.00
# mean          840.28         84.75        7.28          64.44        61.32
# std          2764.32         20.45        6.46          21.17        21.20
# min            45.00         14.00        0.10           7.00         5.90
# 25%           136.78         74.75        2.18          50.00        49.90
# 50%           236.65         96.00        5.60          67.00        64.20
# 75%           480.06        100.00       10.62          80.25        78.00
# max         30781.00        100.00       29.50          99.00        97.70
#
#        Compliance  Best Practices   Latency  Documentation    WsRF   Class
# count      364.00          364.00    364.00         364.00  364.00  364.00
# mean        83.68           80.69    763.48          47.53   66.65    2.78
# std          8.77            6.69   2755.56          36.40   11.51    0.98
# min         67.00           58.00     31.50           1.00   30.00    1.00
# 25%         78.00           77.00    121.88           9.00   59.00    2.00
# 50%         78.00           83.00    180.93          39.00   67.50    3.00
# 75%         89.00           84.00    409.27          89.00   74.25    4.00
# max        100.00           95.00  30781.00          97.00  100.00    4.00

# %%
rt = np.array(qws["Response Time"]).reshape(-1,1)

# %%
av = np.array(qws["Availability"]).reshape(-1,1)

# %%
sc = np.array(qws["Succesability"]).reshape(-1,1)

# %%
rb = np.array(qws["Reliability"]).reshape(-1,1)

# %%
cp = np.array(qws["Compliance"]).reshape(-1,1)

# %%
bp = np.array(qws["Best Practices"]).reshape(-1,1)

# %%
lt = np.array(qws["Latency"]).reshape(-1,1)

# %%
dc = np.array(qws["Documentation"]).reshape(-1,1)

# %%
ws = np.array(qws["WsRF"]).reshape(-1,1)

# %%
thr = np.array(qws["Throughput"]).reshape(-1,1)

# %% [markdown]
# ## Fuzzy Logic

# %%
# !pip install scikit-fuzzy
# Out:
# Requirement already satisfied: scikit-fuzzy in c:\users\aferr\anaconda3\lib\site-packages (0.4.2)
# Requirement already satisfied: numpy>=1.6.0 in c:\users\aferr\anaconda3\lib\site-packages (from scikit-fuzzy) (1.17.4)
# Requirement already satisfied: scipy>=0.9.0 in c:\users\aferr\anaconda3\lib\site-packages (from scikit-fuzzy) (1.4.1)
# Requirement already satisfied: networkx>=1.9.0 in c:\users\aferr\anaconda3\lib\site-packages (from scikit-fuzzy) (2.5)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\aferr\anaconda3\lib\site-packages (from networkx>=1.9.0->scikit-fuzzy) (4.4.0)

# %% [markdown]
# ## Trapezoidal_parâmetros_especialistas

# %%
# variáveis de entrada ou antecedentes, que influenciam a avaliação do serviço
Availability = ctrl.Antecedent(np.arange(0.1, 101.1, .01), 'availability')
Reliability = ctrl.Antecedent(np.arange(5.9,98.7, .5), 'reliability')
Response_Time = ctrl.Antecedent(np.arange(45,30782, 1), 'response_time')
Throughput = ctrl.Antecedent(np.arange(0.1,30, .1), 'throughput')
Lattency = ctrl.Antecedent(np.arange(31.5,30782,.5), 'lattency')
# variável de saída ou consequente, avaliação do serviço
WsRF = ctrl.Consequent(np.arange(30, 101, .25), 'WsRF')

# DEFINIÇÕES DAS FUNÇÕES DE PERTINÊNCIA -- sobre todas as variáveis: entrada & saída
# Availability
Availability['baixa'] = fuzz.trapmf(Availability.universe,[0,0,20,35])
Availability['media'] = fuzz.trapmf(Availability.universe,[25,40,60,75])
Availability['alta'] = fuzz.trapmf(Availability.universe,[60,80,100,100])

# Reliability
Reliability['baixo'] = fuzz.trapmf(Reliability.universe,[5.9,5.9,25,30])
Reliability['medio'] = fuzz.trapmf(Reliability.universe,[20,40,60,75])
Reliability['alto'] = fuzz.trapmf(Reliability.universe,[50,75,98.7,98.7])

Response_Time['baixo'] = fuzz.trapmf(Response_Time.universe,[45,45,4000,7500])
Response_Time['medio'] = fuzz.trapmf(Response_Time.universe,[5000,12000,17000,22500])
Response_Time['alto'] = fuzz.trapmf(Response_Time.universe, [15000,25000,30782,30782])

Throughput['baixo'] = fuzz.trapmf(Throughput.universe,[0.1,0.1,4,7.5])
Throughput['medio'] = fuzz.trapmf(Throughput.universe,[5,10,16,22.5])
Throughput['alto'] = fuzz.trapmf(Throughput.universe,[15,23,30,30])

Lattency['baixo'] = fuzz.trapmf(Lattency.universe,[31.5,31.5,5000,7500])
Lattency['medio'] = fuzz.trapmf(Lattency.universe,[5000,10000,15000,20000])
Lattency['alto'] = fuzz.trapmf(Lattency.universe,[15000,22500,30782,30782])

# WsRF
WsRF['ruim'] = fuzz.trapmf(WsRF.universe,[30,30,40,55])
WsRF['medio'] = fuzz.trapmf(WsRF.universe,[47,55,75,82])
WsRF['bom'] = fuzz.trapmf(WsRF.universe,[75,85,101,101])

# regra 1 - 
regra1 = ctrl.Rule(Availability['baixa'] & Reliability['baixo'] & Response_Time['alto'] & Lattency['alto']
 & Throughput['baixo'], WsRF['ruim'])

# regra 2 - 
regra2 = ctrl.Rule(Availability['media'] & Reliability['medio'] & Response_Time['medio'] & Lattency['medio'] 
 & Throughput['medio'], WsRF['medio'])

# regra 3 - 
regra3 = ctrl.Rule(Availability['alta'] & Reliability['alto'] & Response_Time['baixo'] & Lattency['baixo'] 
 & Throughput['alto'] , WsRF['bom'])
# com 3 regras, não se consegue calcular tudo, somente o primeiro fornece.
# acrescer 2 novas regras... erro cai para 9%, mas não cobre todos os casos.

# regra 4 (adicional)
regra4 = ctrl.Rule(Availability['alta'] | Reliability['medio'] & Response_Time['medio'] & Throughput['alto'] &
        Lattency['medio'], WsRF['medio'])

# regra 5 (adicional)
regra5 = ctrl.Rule(Availability['media'] | Reliability['medio'] & Response_Time['alto'] & Throughput['medio'] &
                   Lattency['alto'], WsRF['ruim'])

regra_ctrl = ctrl.ControlSystem([regra1, regra2, regra3, regra4, regra5])
engine = ctrl.ControlSystemSimulation(regra_ctrl)

# %%
# passa as predições dos modelos para suas respectivas variáveis de entrada
z =list(range(0,365))
s = 0
for i in z:
    engine.input['availability'] = av[i]
    engine.input['reliability'] = rb[i]
    engine.input['response_time'] = rt[i]
    engine.input['lattency'] = lt[i]
    engine.input['throughput'] = thr[i]
    engine.compute()
    e = (ws[i]-engine.output['WsRF'])/ws[i]
    ep = e * 100
    s = s + ep
    ec = s/(i+1)
    print(i)
    print(engine.output['WsRF'])
    print(ep)
    print(ec)
# Out:
# 0
# [75.57746497]
# [24.42253503]
# [24.42253503]
# 1
# [64.72727273]
# [30.40078201]
# [27.41165852]
# 2
# [75.57746497]
# [16.02503892]
# [23.61611866]
# 3
# [64.72727273]
# [28.08080808]
# [24.73229101]
# 4
# [70.60506009]
# [21.54993323]
# [24.09581946]
# 5
# [75.57746497]
# [16.02503892]
# [22.75068937]
# 6
# [64.72727273]
# [27.27272727]
# [23.39669478]
# 7
# [68.34525326]
# [22.33493948]
# [23.26397537]
# [64.72727273]
# [-6.11028316]
# [11.12188659]
# 254
# [66.44680733]
# [-8.92919234]
# [11.04325491]
# 255
# [64.72727273]
# [-6.11028316]
# [10.9762489]
# 256
# [64.72727273]
# [-6.11028316]
# [10.90976434]
# 257
# [64.72727273]
# [-6.11028316]
# [10.84379516]
# 258
# [64.72727273]
# [-6.11028316]
# [10.7783354]
# 259
# [64.72727273]
# [-6.11028316]
# [10.71337917]
# 260
# [64.72727273]
# [-6.11028316]
# [10.6489207]
# 261
# [64.72727273]
# [-7.87878788]
# [10.57820425]
# 262
# [64.72727273]
# [-7.87878788]
# [10.50802558]
# 263
# [64.72727273]
# [-7.87878788]
# [10.43837856]
# 264
# [64.72727273]
# [-7.87878788]
# [10.36925717]
# 265
# [39.28571429]
# [34.52380952]
# [10.46006376]
# 266
# [39.28571429]
# [34.52380952]
# [10.55019015]
# 267
# [45.77816701]
# [23.70305498]
# [10.599268]
# 268
# [64.70707965]
# [-7.84513274]
# [10.53070146]
# 269
# [64.72727273]
# [-7.87878788]
# [10.46251816]
# 270
# [64.72727273]
# [-7.87878788]
# [10.39483807]
# 271
# [64.72727273]
# [-9.70724191]
# [10.32093336]
# 272
# [64.72727273]
# [-9.70724191]
# [10.24757008]
# 273
# [64.72727273]
# [-9.70724191]
# [10.1747423]
# 274
# [47.67409645]
# [19.19644669]
# [10.2075485]
# 275
# [61.89255255]
# [-4.90263144]
# [10.15280147]
# 276
# [61.89255255]
# [-4.90263144]
# [10.09844973]
# 277
# [39.28571429]
# [33.41404358]
# [10.18231877]
# 278
# [64.72727273]
# [-9.70724191]
# [10.11103002]
# 279
# [64.72727273]
# [-9.70724191]
# [10.04025048]
# 280
# [64.70707965]
# [-11.56393042]
# [9.96336727]
# 281
# [64.72727273]
# [-11.59874608]
# [9.88690588]
# 282
# [45.77816701]
# [21.07212584]
# [9.92642962]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-59-fbc9ff8d7f38> in <module>
#       8     engine.input['lattency'] = lt[i]
#       9     engine.input['throughput'] = thr[i]
# ---> 10     engine.compute()
#      11     e = (ws[i]-engine.output['WsRF'])/ws[i]
#      12     ep = e * 100
#
# ~\Anaconda3\lib\site-packages\skfuzzy\control\controlsystem.py in compute(self)
#     371         for consequent in self.ctrl.consequents:
#     372             consequent.output[self] = \
# --> 373                 CrispValueCalculator(consequent, self).defuzz()
#     374             self.output[consequent.label] = consequent.output[self]
#     375
#
# ~\Anaconda3\lib\site-packages\skfuzzy\control\controlsystem.py in defuzz(self)
#     600             for out in it:
#     601                 universe, mf = self.find_memberships_nd(it.multi_index)
# --> 602                 out[...] = defuzz(universe, mf, self.var.defuzzify_method)
#     603
#     604             return output
#
# ~\Anaconda3\lib\site-packages\skfuzzy\defuzzify\defuzz.py in defuzz(x, mfx, mode)
#     246     if 'centroid' in mode or 'bisector' in mode:
#     247         zero_truth_degree = mfx.sum() == 0  # Approximation of total area
# --> 248         assert not zero_truth_degree, 'Total area is zero in defuzzification!'
#     249
#     250         if 'centroid' in mode:
#
# AssertionError: Total area is zero in defuzzification!
